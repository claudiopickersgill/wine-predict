# %%
import pandas as pd
import matplotlib as plt
import utils_config
config_file="../config.json"
config = utils_config.load_config(config_file)

# %%
data = '../data/winequalityN.csv'

# %%
red = config.red
sep = config.sep

# %%
pd.read_csv(red, sep=sep)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 0               7.4             0.700         0.00             1.9      0.076  \
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wines = pd.read_csv(data)

# %%
wines.head(10)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar
# 0  white            7.0              0.27         0.36            20.7  \
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
# 5  white            8.1              0.28         0.40             6.9
# 6  white            6.2              0.32         0.16             7.0
# 7  white            7.0              0.27         0.36            20.7
# 8  white            6.3              0.30         0.34             1.6
# 9  white            8.1              0.22         0.43             1.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH
# 0      0.045                 45.0                 170.0   1.0010  3.00  \
# ...

# %%
red = wines[wines['type']=='red'].copy()
white = wines[wines['type']=='white'].copy()

# %%
print(f'Total Observations: {wines.shape[0]}')
print(f'Red Wines: {red.shape[0]}')
print(f'White Wines: {white.shape[0]}')
# Out:
# Total Observations: 6497
# Red Wines: 1599
# White Wines: 4898

# %%
red.quality.value_counts().sort_index().plot.bar(width=0.9)
# Out:
# <Axes: xlabel='quality'>

# %%
red["category"] = (red.quality > 5).astype(float)

# %%
white.quality.value_counts().sort_index().plot.bar(width=0.9)
# Out:
# <Axes: xlabel='quality'>

# %%
white["category"] = (white.quality > 5).astype(float)

# %%
vars = [
   'fixed acidity',
   'volatile acidity',
   'citric acid',
   'residual sugar',
   'chlorides',
   'free sulfur dioxide',
   'total sulfur dioxide',
   'density',
   'pH',
   'sulphates',
   'alcohol',
]
